# %% [markdown]
# <a href="https://colab.research.google.com/github/ucaokylong/agents_stuff/blob/main/AI_Search_Agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Yêu cầu:
# - [OpenAI key](https://platform.openai.com/settings/organization/api-keys) để làm backend LLMs
# - [Serp API](https://serper.dev/api-key) key để tìm trên Google

# %%
# !pip install serpapi
# !pip install google-search-results
# Out:
# Collecting serpapi
#   Downloading serpapi-0.1.5-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from serpapi) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi) (2025.1.31)
# Downloading serpapi-0.1.5-py2.py3-none-any.whl (10 kB)
# Installing collected packages: serpapi
# Successfully installed serpapi-0.1.5
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (2025.1.31)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32009 sha256=612c4aa8481f0d3c57ad9dc5fbd79e602e27900f252e639d08f84e3b7cb35a9a
#   Stored in directory: /root/.cache/pip/wheels/6e/42/3e/aeb691b02cb7175ec70e2da04b5658d4739d2b41e5f73cd06f
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2

# %%
from openai import OpenAI
from google.colab import userdata

def reasoning_step(state, user_input, intermediate_results):
    client = OpenAI(api_key=userdata.get('open_ai_key'))

    # Construct the assistant message dynamically with the state, user input, and intermediate results
    messages = [
        {
            "role": "system",
            "content": (
                "You are a reasoning and acting agent. Based on the current state and user input, decide the next action.\n"
                f"State: {state}\n"
                f"User Input: {user_input}\n"
                f"Intermediate Results: {intermediate_results}\n\n"
                "Respond with one of these actions:\n"
                "- Search(query)\n"
                "- Do nothing\n"
                "- Summarize(results)\n"
            )
        }
    ]

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=messages,
        response_format={
            "type": "json_schema",
            "json_schema": {
                "name": "agent_schema",
                "schema": {
                    "type": "object",
                    "required": [],
                    "properties": {}
                },
                "strict": False
            }
        },
        tools=[
            {
                "type": "function",
                "function": {
                    "name": "search_action",
                    "strict": True,
                    "parameters": {
                        "type": "object",
                        "required": ["query"],
                        "properties": {
                            "query": {
                                "type": "string",
                                "description": "The search query string to be submitted to the search engine."
                            }
                        },
                        "additionalProperties": False
                    },
                    "description": "Performs a search using the SERP API and returns the organic results."
                }
            },
            {
                "type": "function",
                "function": {
                    "name": "do_nothing",
                    "strict": True,
                    "parameters": {
                        "type": "object",
                        "required": [],
                        "properties": {},
                        "additionalProperties": False
                    },
                    "description": "A function that performs no action."
                }
            },
            {
                "type": "function",
                "function": {
                    "name": "summarize_action",
                    "description": "Summarizes product results using OpenAI's GPT-4 model",
                    "parameters": {
                    "type": "object",
                    "required": [
                        "results"
                    ],
                    "properties": {
                        "results": {
                        "type": "string",
                        "description": "The product results to summarize"
                        }
                    },
                    "additionalProperties": False
                    },
                    "strict": True
                }
            }
        ],
        tool_choice="required",
        temperature=1,
        max_completion_tokens=2048,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response

# %% [markdown]
# Giả sử chưa search bao giờ:

# %%
assistant_message = reasoning_step(
    "start",
    "iphone 14 price?",
    []
).choices[0].message

# %%
assistant_message
# Out:
# ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_TrusIexZ45jCThW8TlLu8vuw', function=Function(arguments='{"query":"iPhone 14 price"}', name='search_action'), type='function')], annotations=[])

# %% [markdown]
# Đã search và có thông tin rồi

# %%
assistant_message = reasoning_step(
    "start",
    "iphone 14 price?",
    [{
            "action": "search_action",
            "parameters": "iPhone 14 price",
            "result": "iPhone 15 is $1000"
    }
     ]
).choices[0].message

# %%
assistant_message
# Out:
# ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_awKDh75nSER0AjPFWEmSo93l', function=Function(arguments='{"query": "iPhone 14 price"}', name='search_action'), type='function'), ChatCompletionMessageToolCall(id='call_BHWS6yOP5KMMVykyo61M88Q0', function=Function(arguments='{"results": "iPhone 15 is $1000"}', name='summarize_action'), type='function')], annotations=[])

# %% [markdown]
# Đánh giá chất lượng

# %% [markdown]
# ```
# Query: iphone 14 price?
# Expect: trong output cuối cùng có giá $500
#
# ```

# %%
def process_tool_calls(response):
    # Extract tool call information from the response
    tool_calls = response.tool_calls

    if tool_calls:
        # Extract tool function details
        tool_call_id = tool_calls[0].id
        tool_function_name = tool_calls[0].function.name
        tool_query_string = eval(tool_calls[0].function.arguments)

        # Print extracted details
        print('Tool Function Name:', tool_function_name)
        print('Tool Query String:', tool_query_string)

        return tool_function_name, tool_query_string

    else:
        print("No tool calls identified.")
        return None, None

process_tool_calls(assistant_message)
# Out:
# Tool Function Name: search_action
# Tool Query String: {'query': 'iPhone 14 price'}
# ('search_action', {'query': 'iPhone 14 price'})

# %%
def search_action(query):
    from serpapi import GoogleSearch
    api_key = userdata.get("serpapi")
    search = GoogleSearch({"q": query, "api_key": api_key, "num": 10})
    results = search.get_dict()

    info = []

    print('--->', results)

    for item in results['organic_results']:
        info.append(item['snippet'])
    return "\n".join(info)

# %%
search_action("Thời tiết hôm nay Hà Nội đi bơi ở Hồ Gươm")
# Out:
# ---> {'search_metadata': {'id': '67dbd7e938479b69a3934d48', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/166e6e3cf41e4bbb/67dbd7e938479b69a3934d48.json', 'created_at': '2025-03-20 08:55:05 UTC', 'processed_at': '2025-03-20 08:55:05 UTC', 'google_url': 'https://www.google.com/search?q=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+H%C3%A0+N%E1%BB%99i+%C4%91i+b%C6%A1i+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&oq=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+H%C3%A0+N%E1%BB%99i+%C4%91i+b%C6%A1i+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&num=10&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/166e6e3cf41e4bbb/67dbd7e938479b69a3934d48.html', 'total_time_taken': 1.4}, 'search_parameters': {'engine': 'google', 'q': 'Thời tiết hôm nay Hà Nội đi bơi ở Hồ Gươm', 'google_domain': 'google.com', 'num': '10', 'device': 'desktop'}, 'search_information': {'query_displayed': 'Thời tiết hôm nay Hà Nội đi bơi ở Hồ Gươm', 'total_results': 59800, 'time_taken_displayed': 0.32, 'organic_results_state': 'Results for exact spelling'}, 'organic_results': [{'position': 1, 'title': 'Thời tiết hiện tại ở Hoàn Kiếm, Hà Nội, Việt Nam', 'link': 'https://www.accuweather.com/vi/vn/hoan-kiem/425226/current-weather/425226', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.accuweather.com/vi/vn/hoan-kiem/425226/current-weather/425226&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQFnoECB8QAQ', 'displayed_link': 'https://www.accuweather.com › cu...', 'favicon': 'https://serpapi.com/searches/67dbd7e938479b69a3934d48/images/f4c3541454ece06d159bb73af592c0066f0119c43e643b18efe97115bd1b8237.png', 'snippet': 'Thời tiết hiện tại ; RealFeel®. 62° ; Gió. B 5 mi/h ; Gió giật mạnh. 10 mi/h ; Độ ẩm. 58% ; Điểm sương. 48° F.', 'snippet_highlighted_words': ['Thời tiết'], 'missing': ['bơi'], 'must_include': {'word': 'bơi', 'link': 'https://www.google.com/search?sca_esv=94c092591444690d&q=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+H%C3%A0+N%E1%BB%99i+%C4%91i+%22b%C6%A1i%22+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&sa=X&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQ5t4CegQIKhAB'}, 'source': 'AccuWeather'}, {'position': 2, 'title': 'Thời tiết Hà Nội', 'link': 'https://nchmf.gov.vn/Kttvsite/vi-VN/1/ha-noi-w28.html', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://nchmf.gov.vn/Kttvsite/vi-VN/1/ha-noi-w28.html&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQFnoECBkQAQ', 'displayed_link': 'https://nchmf.gov.vn › ha-noi-w28', 'favicon': 'https://serpapi.com/searches/67dbd7e938479b69a3934d48/images/f4c3541454ece06d159bb73af592c006aaa4c4e7a84b822191b518b17afc9980.png', 'snippet': 'Thời tiết; Thời tiết 10 ngày tới. Thời tiết Hà Nội. Thời tiết hiện tại. Cập nhật: 7h 20/03/2025. Nhiệt độ. : 18°C. Thời tiết. : Nhiều mây, không mưa. Độ ẩm.', 'snippet_highlighted_words': ['Thời tiết', 'Thời tiết', 'Thời tiết Hà Nội', 'Thời tiết', 'Thời tiết'], 'missing': ['đi', 'bơi', 'Hồ', 'Gươm'], 'source': 'Trung tâm Dự báo KTTV quốc gia'}, {'position': 3, 'title': 'Thời tiết hàng giờ ở Hoàn Kiếm, Hà Nội, Việt Nam', 'link': 'https://www.accuweather.com/vi/vn/hoan-kiem/425226/hourly-weather-forecast/425226', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.accuweather.com/vi/vn/hoan-kiem/425226/hourly-weather-forecast/425226&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQFnoECBwQAQ', 'displayed_link': 'https://www.accuweather.com › h...', 'favicon': 'https://serpapi.com/searches/67dbd7e938479b69a3934d48/images/f4c3541454ece06d159bb73af592c00605dea1afb37db629ae313291b25e010c.png', 'snippet': 'RealFeel Shade™57°. GióTB 7 mi/h. Chất lượng không khíRất có hại. Chỉ số UV tối đa1 Thấp. Gió giật7 mi/h. Độ ẩm67%. Điểm sương48° F. Mật độ mây0%.', 'missing': ['đi', 'bơi'], 'source': 'AccuWeather'}, {'position': 4, 'title': 'Thời tiết Hà Nội hiện tại và dự báo thời tiết 7 ngày tới', 'link': 'https://vnexpress.net/thoi-tiet/ha-noi', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url= ...
# 'Thời tiết hiện tại ; RealFeel®. 62° ; Gió. B 5 mi/h ; Gió giật mạnh. 10 mi/h ; Độ ẩm. 58% ; Điểm sương. 48° F.\nThời tiết; Thời tiết 10 ngày tới. Thời tiết Hà Nội. Thời tiết hiện tại. Cập nhật: 7h 20/03/2025. Nhiệt độ. : 18°C. Thời tiết. : Nhiều mây, không mưa. Độ ẩm.\nRealFeel Shade™57°. GióTB 7 mi/h. Chất lượng không khíRất có hại. Chỉ số UV tối đa1 Thấp. Gió giật7 mi/h. Độ ẩm67%. Điểm sương48° F. Mật độ mây0%.\nTiếp xúc quá mức với ánh sáng mặt trời trong thời gian ngắn sẽ gây bỏng nắng, tổn thương mắt như đục thủy tinh thể, da bị bỏng, khô, sạm, tạo nếp nhăn, lão hóa ...\nThời tiết Quận Hoàn Kiếm - Hà Nội những ngày tới ; Hôm nay. Nhiều mây. 53 % · 16.4 °C · /. 18.4 °C ; T4 Ngày 19. Nhiều mây. 65 % · 15.8 °C · /. 21.9 °C ; T5 Ngày 20.\n16 ° / 16 °. Mây đen u ám. 3 %. Mây đen u ám. Thời tiết 48h. Thời tiết Hoàn Kiếm - Hà Nội những ngày tới. Hiện tại. 14° / 19°. Mưa nhẹ. 100 %. 18.83 km/h. Ngày/ ...\nIn Hoàn Kiếm, mùa ẩm ướt thì nóng, ngột ngạt và mây bao phủ và mùa khô thì thoải mái, ẩm ướt và gần như trong xanh. Theo diễn tiến trong năm, nhiệt độ thường ...\nHãy đến với Biển Đông, nơi bạn có thể đắm mình trong làn nước ấm áp, xua tan đi cái lạnh của mùa đông. Dù trời có se lạnh, không gian ở đây luôn ...\nDạo 1 vòng quanh Hà Nội ngày rét đậm 10 độ C: Người trùm che kín mít, người đốt lửa sưởi ấm · Thời tiết rét đậm, rét hại ở miền Bắc kéo dài đến bao giờ? 07/02/ ...\n(Truyền hình VTC14) - Các hồ bơi Hà Nội quá tải vì thời tiết nắng nóng Nắng nóng oi bức, cộng với thời điểm học sinh được nghỉ hè là nguyên ...'

# %%
def do_nothing():
    return None

# %%
def summarize_action(results):
    client = OpenAI(api_key=userdata.get('open_ai_key'))
    prompt = f"Summarize the following product results:\n{results}"

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "user", "content": prompt},
        ]
    )
    return response.choices[0].message.content

# %%
def answer_question(question, search_results):
    client = OpenAI(api_key=userdata.get('open_ai_key'))
    prompt = f"Answer the following question using the provided search results:\n\nQuestion: {question}\n\nSearch Results:\n{search_results}"
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "user", "content": prompt},
        ]
    )
    return response.choices[0].message.content

# %%
function_mapping = {
    "search_action": search_action,
    "do_nothing": do_nothing,
    "summarize_action": summarize_action,
    "answer_question": answer_question,
}

# %%
function_mapping["search_action"]("Thời tiết hôm nay Hà Nội đi bơi ở Hồ Gươm")
# Out:
# ---> {'search_metadata': {'id': '67dbd7e938479b69a3934d48', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/166e6e3cf41e4bbb/67dbd7e938479b69a3934d48.json', 'created_at': '2025-03-20 08:55:05 UTC', 'processed_at': '2025-03-20 08:55:05 UTC', 'google_url': 'https://www.google.com/search?q=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+H%C3%A0+N%E1%BB%99i+%C4%91i+b%C6%A1i+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&oq=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+H%C3%A0+N%E1%BB%99i+%C4%91i+b%C6%A1i+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&num=10&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/166e6e3cf41e4bbb/67dbd7e938479b69a3934d48.html', 'total_time_taken': 1.4}, 'search_parameters': {'engine': 'google', 'q': 'Thời tiết hôm nay Hà Nội đi bơi ở Hồ Gươm', 'google_domain': 'google.com', 'num': '10', 'device': 'desktop'}, 'search_information': {'query_displayed': 'Thời tiết hôm nay Hà Nội đi bơi ở Hồ Gươm', 'total_results': 59800, 'time_taken_displayed': 0.32, 'organic_results_state': 'Results for exact spelling'}, 'organic_results': [{'position': 1, 'title': 'Thời tiết hiện tại ở Hoàn Kiếm, Hà Nội, Việt Nam', 'link': 'https://www.accuweather.com/vi/vn/hoan-kiem/425226/current-weather/425226', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.accuweather.com/vi/vn/hoan-kiem/425226/current-weather/425226&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQFnoECB8QAQ', 'displayed_link': 'https://www.accuweather.com › cu...', 'favicon': 'https://serpapi.com/searches/67dbd7e938479b69a3934d48/images/f4c3541454ece06d159bb73af592c0066f0119c43e643b18efe97115bd1b8237.png', 'snippet': 'Thời tiết hiện tại ; RealFeel®. 62° ; Gió. B 5 mi/h ; Gió giật mạnh. 10 mi/h ; Độ ẩm. 58% ; Điểm sương. 48° F.', 'snippet_highlighted_words': ['Thời tiết'], 'missing': ['bơi'], 'must_include': {'word': 'bơi', 'link': 'https://www.google.com/search?sca_esv=94c092591444690d&q=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+H%C3%A0+N%E1%BB%99i+%C4%91i+%22b%C6%A1i%22+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&sa=X&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQ5t4CegQIKhAB'}, 'source': 'AccuWeather'}, {'position': 2, 'title': 'Thời tiết Hà Nội', 'link': 'https://nchmf.gov.vn/Kttvsite/vi-VN/1/ha-noi-w28.html', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://nchmf.gov.vn/Kttvsite/vi-VN/1/ha-noi-w28.html&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQFnoECBkQAQ', 'displayed_link': 'https://nchmf.gov.vn › ha-noi-w28', 'favicon': 'https://serpapi.com/searches/67dbd7e938479b69a3934d48/images/f4c3541454ece06d159bb73af592c006aaa4c4e7a84b822191b518b17afc9980.png', 'snippet': 'Thời tiết; Thời tiết 10 ngày tới. Thời tiết Hà Nội. Thời tiết hiện tại. Cập nhật: 7h 20/03/2025. Nhiệt độ. : 18°C. Thời tiết. : Nhiều mây, không mưa. Độ ẩm.', 'snippet_highlighted_words': ['Thời tiết', 'Thời tiết', 'Thời tiết Hà Nội', 'Thời tiết', 'Thời tiết'], 'missing': ['đi', 'bơi', 'Hồ', 'Gươm'], 'source': 'Trung tâm Dự báo KTTV quốc gia'}, {'position': 3, 'title': 'Thời tiết hàng giờ ở Hoàn Kiếm, Hà Nội, Việt Nam', 'link': 'https://www.accuweather.com/vi/vn/hoan-kiem/425226/hourly-weather-forecast/425226', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.accuweather.com/vi/vn/hoan-kiem/425226/hourly-weather-forecast/425226&ved=2ahUKEwiig-DapJiMAxUtGVkFHaa-ARIQFnoECBwQAQ', 'displayed_link': 'https://www.accuweather.com › h...', 'favicon': 'https://serpapi.com/searches/67dbd7e938479b69a3934d48/images/f4c3541454ece06d159bb73af592c00605dea1afb37db629ae313291b25e010c.png', 'snippet': 'RealFeel Shade™57°. GióTB 7 mi/h. Chất lượng không khíRất có hại. Chỉ số UV tối đa1 Thấp. Gió giật7 mi/h. Độ ẩm67%. Điểm sương48° F. Mật độ mây0%.', 'missing': ['đi', 'bơi'], 'source': 'AccuWeather'}, {'position': 4, 'title': 'Thời tiết Hà Nội hiện tại và dự báo thời tiết 7 ngày tới', 'link': 'https://vnexpress.net/thoi-tiet/ha-noi', 'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url= ...
# 'Thời tiết hiện tại ; RealFeel®. 62° ; Gió. B 5 mi/h ; Gió giật mạnh. 10 mi/h ; Độ ẩm. 58% ; Điểm sương. 48° F.\nThời tiết; Thời tiết 10 ngày tới. Thời tiết Hà Nội. Thời tiết hiện tại. Cập nhật: 7h 20/03/2025. Nhiệt độ. : 18°C. Thời tiết. : Nhiều mây, không mưa. Độ ẩm.\nRealFeel Shade™57°. GióTB 7 mi/h. Chất lượng không khíRất có hại. Chỉ số UV tối đa1 Thấp. Gió giật7 mi/h. Độ ẩm67%. Điểm sương48° F. Mật độ mây0%.\nTiếp xúc quá mức với ánh sáng mặt trời trong thời gian ngắn sẽ gây bỏng nắng, tổn thương mắt như đục thủy tinh thể, da bị bỏng, khô, sạm, tạo nếp nhăn, lão hóa ...\nThời tiết Quận Hoàn Kiếm - Hà Nội những ngày tới ; Hôm nay. Nhiều mây. 53 % · 16.4 °C · /. 18.4 °C ; T4 Ngày 19. Nhiều mây. 65 % · 15.8 °C · /. 21.9 °C ; T5 Ngày 20.\n16 ° / 16 °. Mây đen u ám. 3 %. Mây đen u ám. Thời tiết 48h. Thời tiết Hoàn Kiếm - Hà Nội những ngày tới. Hiện tại. 14° / 19°. Mưa nhẹ. 100 %. 18.83 km/h. Ngày/ ...\nIn Hoàn Kiếm, mùa ẩm ướt thì nóng, ngột ngạt và mây bao phủ và mùa khô thì thoải mái, ẩm ướt và gần như trong xanh. Theo diễn tiến trong năm, nhiệt độ thường ...\nHãy đến với Biển Đông, nơi bạn có thể đắm mình trong làn nước ấm áp, xua tan đi cái lạnh của mùa đông. Dù trời có se lạnh, không gian ở đây luôn ...\nDạo 1 vòng quanh Hà Nội ngày rét đậm 10 độ C: Người trùm che kín mít, người đốt lửa sưởi ấm · Thời tiết rét đậm, rét hại ở miền Bắc kéo dài đến bao giờ? 07/02/ ...\n(Truyền hình VTC14) - Các hồ bơi Hà Nội quá tải vì thời tiết nắng nóng Nắng nóng oi bức, cộng với thời điểm học sinh được nghỉ hè là nguyên ...'

# %%
# function_to_call = function_mapping[tool_function_name]
# function_response = function_to_call(**tool_query_string)

# %%
from openai import OpenAI
from google.colab import userdata

def reasoning_step_advanced(state, user_input, intermediate_results):
    client = OpenAI(api_key=userdata.get('open_ai_key'))

    # Construct the assistant message dynamically with the state, user input, and intermediate results
    messages = [
        {
            "role": "system",
            "content": (
                "You are a reasoning and acting agent. Based on the current state and user input, decide the next action.\n"
                f"State: {state}\n"
                f"User Input: {user_input}\n"
                f"Intermediate Results: {intermediate_results}\n\n"
                "Respond with one of these actions:\n"
                "- Search(query)\n"
                "- Do nothing\n"
                "- answer_question(results)\n"
            )
        }
    ]

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=messages,
        response_format={
            "type": "json_schema",
            "json_schema": {
                "name": "agent_schema",
                "schema": {
                    "type": "object",
                    "required": [],
                    "properties": {}
                },
                "strict": False
            }
        },
        tools=[
            {
                "type": "function",
                "function": {
                    "name": "search_action",
                    "strict": True,
                    "parameters": {
                        "type": "object",
                        "required": ["query"],
                        "properties": {
                            "query": {
                                "type": "string",
                                "description": "The search query string to be submitted to the search engine."
                            }
                        },
                        "additionalProperties": False
                    },
                    "description": "Performs a search using the SERP API and returns the organic results."
                }
            },
            {
                "type": "function",
                "function": {
                    "name": "do_nothing",
                    "strict": True,
                    "parameters": {
                        "type": "object",
                        "required": [],
                        "properties": {},
                        "additionalProperties": False
                    },
                    "description": "A function that performs no action."
                }
            },
            {
                "type": "function",
                "function": {
                    "name": "summarize_action",
                    "description": "Summarizes product results using OpenAI's GPT-4 model",
                    "parameters": {
                    "type": "object",
                    "required": [
                        "results"
                    ],
                    "properties": {
                        "results": {
                        "type": "string",
                        "description": "The product results to summarize"
                        }
                    },
                    "additionalProperties": False
                    },
                    "strict": True
                }
            },
            {
                "type": "function",
                "function": {
                    "name": "answer_question",
                    "description": "Answer question using the search result",
                    "parameters": {
                    "type": "object",
                    "required": [
                        "question",
                        "search_results"
                    ],
                    "properties": {
                        "question": {
                            "type": "string",
                            "description": "The question to be answered"
                        },
                        "search_results": {
                            "type": "string",
                            "description": "The search results from api to answer the question"
                        }
                    },
                    "additionalProperties": False
                    },
                    "strict": True
                }
            }
        ],
        tool_choice="required",
        temperature=1,
        max_completion_tokens=2048,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response

# %%
def react_agent(user_input):
    state = {"status": "start", "history": []}  # Initialize the state with status and history
    intermediate_results = []

    while True:
        # Reasoning step: Decide the next action
        action_response = reasoning_step_advanced(state, user_input, intermediate_results).choices[0].message

        action_response = process_tool_calls(action_response)
        tool_function_name, tool_query_string = action_response

        if tool_function_name == "do_nothing":
            return intermediate_results[-1]["result"]
            break

        # Execute the selected action
        function_to_call = function_mapping[tool_function_name]
        action_result = function_to_call(**tool_query_string)

        print(action_result)

        # Save intermediate results
        intermediate_results.append({
            "action": tool_function_name,
            "parameters": tool_query_string,
            "result": action_result
        })

        # Update state
        state.update({
            "status": "in_progress",
            "last_action": tool_function_name,
            "last_parameters": tool_query_string
            })

    return intermediate_results

user_query = "Thời tiết hôm nay có phù hợp để đi bơi ở Hồ Gươm không?"
final_answer = react_agent(user_query)
print(f"Final Output: {final_answer}")
# Out:
# Tool Function Name: search_action
# Tool Query String: {'query': 'Thời tiết hôm nay ở Hồ Gươm'}
# ---> {'search_metadata': {'id': '67dbd800aff97e1631cef3ea', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/95549bff3dffbc86/67dbd800aff97e1631cef3ea.json', 'created_at': '2025-03-20 08:55:28 UTC', 'processed_at': '2025-03-20 08:55:28 UTC', 'google_url': 'https://www.google.com/search?q=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&oq=Th%E1%BB%9Di+ti%E1%BA%BFt+h%C3%B4m+nay+%E1%BB%9F+H%E1%BB%93+G%C6%B0%C6%A1m&num=10&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/95549bff3dffbc86/67dbd800aff97e1631cef3ea.html', 'total_time_taken': 1.71}, 'search_parameters': {'engine': 'google', 'q': 'Thời tiết hôm nay ở Hồ Gươm', 'google_domain': 'google.com', 'num': '10', 'device': 'desktop'}, 'search_information': {'query_displayed': 'Thời tiết hôm nay ở Hồ Gươm', 'total_results': 875000, 'time_taken_displayed': 0.28, 'organic_results_state': 'Results for exact spelling', 'results_for': 'Hoàn Kiếm Lake, Hang Trong'}, 'knowledge_graph': {'entity_type': 'weather_onebox'}, 'answer_box': {'type': 'weather_result', 'temperature': '78', 'unit': 'Fahrenheit', 'precipitation': '5%', 'humidity': '37%', 'wind': '6 mph', 'location': 'Hoàn Kiếm Lake, Hang Trong', 'date': 'Thursday', 'weather': 'Mostly sunny', 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f755a423893a142a2b31435556ff53e1b.png', 'forecast': [{'day': 'Thursday', 'temperature': {'high': '78', 'low': '57'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a00dad8817b5865ee6859b592327bfb4a6.png', 'weather': 'Mostly sunny', 'humidity': '37%', 'precipitation': '5%', 'wind': '6 mph'}, {'day': 'Friday', 'temperature': {'high': '75', 'low': '58'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a0b173e1b48a75ee06efaf4b6e2ce2db9e.png', 'weather': 'Sunny', 'humidity': '46%', 'precipitation': '0%', 'wind': '7 mph'}, {'day': 'Saturday', 'temperature': {'high': '79', 'low': '61'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a0c6ba51a72c78eb6415af90e1c4728a50.png', 'weather': 'Partly cloudy', 'humidity': '53%', 'precipitation': '5%', 'wind': '8 mph'}, {'day': 'Sunday', 'temperature': {'high': '81', 'low': '64'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a021186ee8bf6fbea94840f6c470ed560d.png', 'weather': 'Partly cloudy', 'humidity': '57%', 'precipitation': '15%', 'wind': '5 mph'}, {'day': 'Monday', 'temperature': {'high': '83', 'low': '67'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a06382bdd6f3a294a57725e52f2e9c8ab7.png', 'weather': 'Sunny', 'humidity': '56%', 'precipitation': '10%', 'wind': '8 mph'}, {'day': 'Tuesday', 'temperature': {'high': '85', 'low': '69'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a042bd248cb41410e8a9497bab650d45e6.png', 'weather': 'Mostly sunny', 'humidity': '56%', 'precipitation': '20%', 'wind': '10 mph'}, {'day': 'Wednesday', 'temperature': {'high': '90', 'low': '72'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a034e03a358477bc51382070db5d982f91.png', 'weather': 'Mostly sunny', 'humidity': '61%', 'precipitation': '20%', 'wind': '8 mph'}, {'day': 'Thursday', 'temperature': {'high': '90', 'low': '71'}, 'thumbnail': 'https://serpapi.com/searches/67dbd800aff97e1631cef3ea/images/43db9961da24541f8c252fec583790a03470d6b98befbb71b7a24d9087a0d003.png', 'weather': 'Partly cloudy', 'humidity': '62%', 'precipitation': '10%', 'wind': '8 mph'}], 'hourly_forecast': [{'time': 'Thursday 3:00\u202fPM', 'thumbnail': 'https://ssl.gstatic.com/onebox/weather/64/partly_cloudy.png', 'weather': 'Partly cloudy', 'temperature': '76', 'precipitation': '0%', 'humidity':  ...
# Thời tiết hiện tại ; RealFeel®. 62° ; Gió. B 5 mi/h ; Gió giật mạnh. 10 mi/h ; Độ ẩm. 58% ; Điểm sương. 48° F.
# RealFeel Shade™57°. GióTB 7 mi/h. Chất lượng không khíRất có hại. Chỉ số UV tối đa1 Thấp. Gió giật7 mi/h. Độ ẩm67%. Điểm sương48° F. Mật độ mây0%.
# Thời tiết Hoàn Kiếm - Hà Nội. Mây đen u ám 16 °. Mây đen u ám. Cảm giác như 16°.
# Thời tiết Quận Hoàn Kiếm - Hà Nội những ngày tới ; Hôm nay. Nhiều mây. 53 % · 16.4 °C · /. 18.4 °C ; T4 Ngày 19. Nhiều mây. 65 % · 15.8 °C · /. 21.9 °C ; T5 Ngày 20.
# Dự báo thời tiết cho Hoàn Kiếm, Hanoi (Hoan Kiem, Hanoi), Hoàn Kiếm - hôm nay, ngày mai, 10 ngày, 7 ngày, Việt Nam. ; thứ hai , 17 tháng 3 · 17° · 2.5. 70% ; thứ ba ...
# Thời tiết hiện tại. Cập nhật: 7h 20/03/2025 · : 18°C ; Dự báo ngày hôm nay. Cập nhật: 04h30 20/03/2025 · : 25°C ; Dự báo đêm hôm nay. Cập nhật: 04h30 20/03/2025 · : ...
# Dự báo thời tiết Quận Hoàn Kiếm - Hà Nội theo giờ. 11:00. 26.2°C / 26.9°C. Mưa nhẹ. 79%. 2.52 km/giờ. Chỉ số UV. 4.43. Tầm nhìn. 10 km. Áp suất. 1012 mb.
# Theo dự báo thời tiết hôm nay, ban ngày miền Bắc tiếp tục có nắng, trời ấm dần. Tuy nhiên ban đêm vẫn khá rét. Nhiệt độ ban đêm giảm đi không ...
# Dự báo thời tiết mới nhất hôm nay ngày 18/3: Bắc Bộ rét sâu, Nam Bộ nắng nóng | ANTV. 14K views · 12 hours ago #antv #dubaothoitiet # ...
# Dự báo chất lượng không khí (AQI⁺) tại Hoàn Kiếm ; Hôm nay. 126. Biểu tượng thời tiết. 50%. 73°. 64°. Bản đồ Chất lượng Không khí IQAir AirVisual Gió xoay 141 độ.
# Tool Function Name: answer_question
# Tool Query String: {'question': 'Thời tiết hôm nay có phù hợp để đi bơi ở Hồ Gươm không?', 'search_results': 'Thời tiết hiện tại ; RealFeel®. 62° ; Gió. B 5 mi/h ; Gió giật mạnh. 10 mi/h ; Độ ẩm. 58% ; Điểm sương. 48° F.\nRealFeel Shade™57°. GióTB 7 mi/h. Chất lượng không khíRất có hại. Chỉ số UV tối đa1 Thấp. Gió giật7 mi/h. Độ ẩm67%. Điểm sương48° F. Mật độ mây0%.\nThời tiết Hoàn Kiếm - Hà Nội. Mây đen u ám 16 °. Mây đen u ám. Cảm giác như 16°.\nThời tiết Quận Hoàn Kiếm - Hà Nội những ngày tới ; Hôm nay. Nhiều mây. 53 % · 16.4 °C · /. 18.4 °C ; T4 Ngày 19. Nhiều mây. 65 % · 15.8 °C · /. 21.9 °C ; T5 Ngày 20.\nDự báo thời tiết cho Hoàn Kiếm, Hanoi (Hoan Kiem, Hanoi), Hoàn Kiếm - hôm nay, ngày mai, 10 ngày, 7 ngày, Việt Nam. ; thứ hai , 17 tháng 3 · 17° · 2.5. 70% ; thứ ba ...\nThời tiết hiện tại. Cập nhật: 7h 20/03/2025 · : 18°C ; Dự báo ngày hôm nay. Cập nhật: 04h30 20/03/2025 · : 25°C ; Dự báo đêm hôm nay. Cập nhật: 04h30 20/03/2025 · : ...\nDự báo thời tiết Quận Hoàn Kiếm - Hà Nội theo giờ. 11:00. 26.2°C / 26.9°C. Mưa nhẹ. 79%. 2.52 km/giờ. Chỉ số UV. 4.43. Tầm nhìn. 10 km. Áp suất. 1012 mb.\nTheo dự báo thời tiết hôm nay, ban ngày miền Bắc tiếp tục có nắng, trời ấm dần. Tuy nhiên ban đêm vẫn khá rét. Nhiệt độ ban đêm giảm đi không ...\nDự báo thời tiết mới nhất hôm nay ngày 18/3: Bắc Bộ rét sâu, Nam Bộ nắng nóng | ANTV. 14K views · 12 hours ago #antv #dubaothoitiet # ...\nDự báo chất lượng không khí (AQI⁺) tại Hoàn Kiếm ; Hôm nay. 126. Biểu tượng thời tiết. 50%. 73°. 64°. Bản đồ Chất lượng Không khí IQAir AirVisual Gió xoay 141 độ.'}
# Thời tiết ở Hồ Gươm hôm nay không thực sự phù hợp để đi bơi do một số lý do sau:
#
# 1. Nhiệt độ: Dự báo thời tiết cho thấy nhiệt độ trong khoảng từ 16°C đến 18°C, khá mát mẻ và không lý tưởng cho việc bơi lội.
#
# 2. Thời tiết: Bầu trời nhiều mây, có mưa nhẹ và độ ẩm cao, không phải điều kiện lý tưởng để đi bơi ngoài trời.
#
# 3. Chất lượng không khí: AQI (Chỉ số chất lượng không khí) tại Hoàn Kiếm ở mức 126, được đánh giá là "rất có hại", không tốt cho sức khỏe khi hoạt động ngoài trời.
#
# Với các điều kiện trên, bạn nên cân nhắc và có thể sẽ muốn chọn một ngày khác phù hợp hơn để đi bơi.
# Tool Function Name: do_nothing
# Tool Query String: {}
# Final Output: Thời tiết ở Hồ Gươm hôm nay không thực sự phù hợp để đi bơi do một số lý do sau:
#
# 1. Nhiệt độ: Dự báo thời tiết cho thấy nhiệt độ trong khoảng từ 16°C đến 18°C, khá mát mẻ và không lý tưởng cho việc bơi lội.
#
# 2. Thời tiết: Bầu trời nhiều mây, có mưa nhẹ và độ ẩm cao, không phải điều kiện lý tưởng để đi bơi ngoài trời.
#
# 3. Chất lượng không khí: AQI (Chỉ số chất lượng không khí) tại Hoàn Kiếm ở mức 126, được đánh giá là "rất có hại", không tốt cho sức khỏe khi hoạt động ngoài trời.
#
# Với các điều kiện trên, bạn nên cân nhắc và có thể sẽ muốn chọn một ngày khác phù hợp hơn để đi bơi.
